# %%
# import required libraries
import pandas as pd
import numpy as np

# %%
# load the raw dataset (adjust path if needed)
df = pd.read_csv("synthetic_banking_conversations_2000.csv")

# quick peek at data and shape
print(f"Loaded shape: {df.shape}")
df.head(3)
# Out:
# Loaded shape: (2000, 24)
#    post_id platform            bank_name  \
# 0  P000001   Reddit  First National Bank
# 1  P000002     Yelp  First National Bank
# 2  P000003   Reddit       SafeTrust Bank
#
#                                            post_text          category  \
# 0  Account flagged for suspicious activity; suppo...  Security & Fraud
# 1  Session keeps timing out while I complete form...    Online Banking
# 2  Found the ATM network reliable in my city, no ...       ATM Service
#
#                 subcategory sentiment_label  sentiment_score        date  \
# 0  Unauthorized Transaction        Positive            0.398  2024-11-23
# 1                        UX        Negative           -0.243  2023-10-12
# 2              Network Down        Positive            0.256  2023-02-14
#
#   user_id  ...  language  country  is_verified    topic_tags  \
# 0  U81482  ...        en       AU         True      security
# 1  U10851  ...        en       CA        False  rewards|loan
# 2  U70217  ...        en       AU         True    support|ux
#
#     extracted_entities urgency_flag  complaint_flag resolved_flag  \
# 0  First National Bank        False           False           NaN
# 1  First National Bank         True           False           NaN
# 2       SafeTrust Bank        False           False           NaN
#
#   response_time_hours                  source_url
# 0                 NaN  https://example.com/post/1
# 1                 NaN  https://example.com/post/2
# 2                 NaN  https://example.com/post/3
#
# [3 rows x 24 columns]

# %%
# look at column names, datatypes, and missing values
print("Columns:", df.columns.tolist())
print("\nDtypes:\n", df.dtypes)
print("\nTop null counts:\n", df.isna().sum().sort_values(ascending=False).head(10))

# preview country and language distribution
print("\nCountry counts:\n", df["country"].value_counts(dropna=False).head(10))
print("\nLanguage counts:\n", df["language"].value_counts(dropna=False).head(10))
# Out:
# Columns: ['post_id', 'platform', 'bank_name', 'post_text', 'category', 'subcategory', 'sentiment_label', 'sentiment_score', 'date', 'user_id', 'user_followers', 'likes', 'shares', 'replies', 'language', 'country', 'is_verified', 'topic_tags', 'extracted_entities', 'urgency_flag', 'complaint_flag', 'resolved_flag', 'response_time_hours', 'source_url']
#
# Dtypes:
#  post_id                 object
# platform                object
# bank_name               object
# post_text               object
# category                object
# subcategory             object
# sentiment_label         object
# sentiment_score        float64
# date                    object
# user_id                 object
# user_followers           int64
# likes                    int64
# shares                   int64
# replies                  int64
# language                object
# country                 object
# is_verified               bool
# topic_tags              object
# extracted_entities      object
# urgency_flag              bool
# complaint_flag            bool
# resolved_flag           object
# response_time_hours    float64
# source_url              object
# dtype: object
#
# Top null counts:
#  response_time_hours    1907
# resolved_flag          1782
# post_id                   0
# platform                  0
# complaint_flag            0
# urgency_flag              0
# extracted_entities        0
# topic_tags                0
# is_verified               0
# country                   0
# dtype: int64
#
# Country counts:
#  country
# IN    357
# US    353
# CA    334
# NG    333
# GB    317
# AU    306
# Name: count, dtype: int64
#
# Language counts:
#  language
# en    1638
# fr     238
# es     124
# Name: count, dtype: int64

# %%
# normalize country formatting (strip spaces, uppercase)
df["country"] = df["country"].apply(lambda x: x.strip().upper() if isinstance(x, str) else x)

# keep only US rows
df_us = df[df["country"] == "US"].copy()

# sanity check: how many rows kept
print(f"Kept {len(df_us)} of {len(df)} rows ({len(df_us)/len(df):.1%}).")

# drop the country column now that we've filtered by it
df_us.drop(columns=["country"], inplace=True)

# quick peek after filtering
df_us.head(3)
# Out:
# Kept 353 of 2000 rows (17.6%).
#     post_id platform      bank_name  \
# 11  P000012     Yelp     GlobalBank
# 14  P000015     Yelp  Maple Savings
# 16  P000017   Forums   Horizon Bank
#
#                                             post_text          category  \
# 11  Cash shortage at ATM during the weekend ruined...       ATM Service
# 14  Spent 45 minutes on hold, then agent was unhel...  Customer Service
# 16  Why is the monthly fee increasing? Feels like ...    Fees & Charges
#
#        subcategory sentiment_label  sentiment_score        date user_id  ...  \
# 11   Cash Shortage        Negative           -1.000  2024-04-07  U25860  ...
# 14  In-branch Help         Neutral           -0.143  2024-04-18  U42742  ...
# 16    Monthly Fees        Negative           -0.756  2024-07-09  U17989  ...
#
#     replies  language  is_verified                 topic_tags  \
# 11        2        en        False  transfer|security|support
# 14        5        fr        False          fees|app|transfer
# 16        2        en         True           transfer|support
#
#    extracted_entities  urgency_flag complaint_flag resolved_flag  \
# 11         GlobalBank          True          False           NaN
# 14      Maple Savings         False          False           NaN
# 16       Horizon Bank          True          False           NaN
#
#     response_time_hours                   source_url
# 11                  NaN  https://example.com/post/12
# 14                  NaN  https://example.com/post/15
# 16                  NaN  https://example.com/post/17
#
# [3 rows x 23 columns]

# %%
# normalize language column (lowercase, strip spaces)
df_us["language"] = df_us["language"].astype(str).str.strip().str.lower()

# keep only rows where language == 'en'
before = len(df_us)
df_us = df_us[df_us["language"] == "en"].copy()

# sanity check: how many rows kept
print(f"Kept {len(df_us)} of {before} rows after filtering for English ({len(df_us)/before:.1%}).")

# quick peek after filtering
df_us.head(3)
# Out:
# Kept 291 of 353 rows after filtering for English (82.4%).
#     post_id platform       bank_name  \
# 11  P000012     Yelp      GlobalBank
# 16  P000017   Forums    Horizon Bank
# 17  P000018   Reddit  Pioneer Credit
#
#                                             post_text         category  \
# 11  Cash shortage at ATM during the weekend ruined...      ATM Service
# 16  Why is the monthly fee increasing? Feels like ...   Fees & Charges
# 17  The banking app keeps crashing when I try to t...  App Performance
#
#       subcategory sentiment_label  sentiment_score        date user_id  ...  \
# 11  Cash Shortage        Negative           -1.000  2024-04-07  U25860  ...
# 16   Monthly Fees        Negative           -0.756  2024-07-09  U17989  ...
# 17   Login Issues        Negative           -1.039  2024-08-06  U42271  ...
#
#     replies  language  is_verified                 topic_tags  \
# 11        2        en        False  transfer|security|support
# 16        2        en         True           transfer|support
# 17        2        en        False           support|transfer
#
#    extracted_entities  urgency_flag complaint_flag resolved_flag  \
# 11         GlobalBank          True          False           NaN
# 16       Horizon Bank          True          False           NaN
# 17     Pioneer Credit         False           True           NaN
#
#     response_time_hours                   source_url
# 11                  NaN  https://example.com/post/12
# 16                  NaN  https://example.com/post/17
# 17                  NaN  https://example.com/post/18
#
# [3 rows x 23 columns]

# %%
# drop columns we don't need for category/sentiment analysis
cols_to_drop = [
    "topic_tags", 
    "extracted_entities", 
    "response_time_hours", 
    "urgency_flag", 
    "complaint_flag"
]

# only drop if the columns actually exist
cols_to_drop = [c for c in cols_to_drop if c in df_us.columns]
df_us.drop(columns=cols_to_drop, inplace=True)

# show remaining columns
print(f"Dropped columns: {cols_to_drop}")
print("Remaining columns:", df_us.columns.tolist())
# Out:
# Dropped columns: ['topic_tags', 'extracted_entities', 'response_time_hours', 'urgency_flag', 'complaint_flag']
# Remaining columns: ['post_id', 'platform', 'bank_name', 'post_text', 'category', 'subcategory', 'sentiment_label', 'sentiment_score', 'date', 'user_id', 'user_followers', 'likes', 'shares', 'replies', 'language', 'is_verified', 'resolved_flag', 'source_url']

# %%
# standardize category values: strip spaces, collapse multi-spaces, title-case
df_us["category"] = (
    df_us["category"]
    .astype(str)
    .str.strip()
    .str.replace(r"\s+", " ", regex=True)
    .str.title()
)

# preview cleaned categories
print("Sample categories:", df_us["category"].unique()[:10])
print("\nTop 10 categories by count:\n", df_us["category"].value_counts().head(10))
# Out:
# Sample categories: ['Atm Service' 'Fees & Charges' 'App Performance' 'Online Banking'
#  'Loan Process' 'Branch Experience' 'Security & Fraud'
#  'International Transfers' 'Interest Rates' 'Customer Service']
#
# Top 10 categories by count:
#  category
# Atm Service          30
# Branch Experience    26
# Online Banking       25
# Fees & Charges       24
# Interest Rates       23
# Customer Service     23
# Account Opening      21
# Credit Card          19
# Loan Process         17
# Notifications        17
# Name: count, dtype: int64

# %%
# convert sentiment_score to numeric and clip to [-1, 1]
df_us["sentiment_score"] = pd.to_numeric(df_us["sentiment_score"], errors="coerce")
df_us["sentiment_score"] = df_us["sentiment_score"].clip(-1, 1)

# preview sentiment_score distribution
print(df_us["sentiment_score"].describe())
print("Sample scores:", df_us["sentiment_score"].head().tolist())
# Out:
# count    291.000000
# mean       0.058330
# std        0.613851
# min       -1.000000
# 25%       -0.424500
# 50%        0.034000
# 75%        0.558500
# max        1.000000
# Name: sentiment_score, dtype: float64
# Sample scores: [-1.0, -0.756, -1.0, 0.449, 0.133]

# %%
# normalize sentiment_label and fill missing ones using sentiment_score
def label_from_score(x):
    if pd.isna(x): return None
    if x >= 0.2: return "Positive"
    if x <= -0.2: return "Negative"
    return "Neutral"

# mark invalid labels as NaN
valid_labels = {"positive", "neutral", "negative"}
df_us["sentiment_label"] = df_us["sentiment_label"].astype(str).str.strip()
df_us.loc[~df_us["sentiment_label"].str.lower().isin(valid_labels), "sentiment_label"] = np.nan

# fill missing labels using score
df_us["sentiment_label"] = df_us["sentiment_label"].fillna(df_us["sentiment_score"].apply(label_from_score))

# capitalize for consistency
df_us["sentiment_label"] = df_us["sentiment_label"].astype(str).str.capitalize()

# preview counts
print(df_us["sentiment_label"].value_counts())
print("Sample labels:", df_us["sentiment_label"].head().tolist())
# Out:
# sentiment_label
# Positive    126
# Negative    114
# Neutral      51
# Name: count, dtype: int64
# Sample labels: ['Negative', 'Negative', 'Negative', 'Positive', 'Neutral']

# %%
# final check: show shape, columns, and a quick preview
print(f"Final cleaned shape: {df_us.shape}")
print("Columns:", df_us.columns.tolist())

print("\nTop 10 categories by count:")
print(df_us["category"].value_counts().head(10))

print("\nSentiment label counts:")
print(df_us["sentiment_label"].value_counts())

print("\nSentiment score summary:")
print(df_us["sentiment_score"].describe())

# show first few rows of cleaned data
df_us.head(10)
# Out:
# Final cleaned shape: (291, 18)
# Columns: ['post_id', 'platform', 'bank_name', 'post_text', 'category', 'subcategory', 'sentiment_label', 'sentiment_score', 'date', 'user_id', 'user_followers', 'likes', 'shares', 'replies', 'language', 'is_verified', 'resolved_flag', 'source_url']
#
# Top 10 categories by count:
# category
# Atm Service          30
# Branch Experience    26
# Online Banking       25
# Fees & Charges       24
# Interest Rates       23
# Customer Service     23
# Account Opening      21
# Credit Card          19
# Loan Process         17
# Notifications        17
# Name: count, dtype: int64
#
# Sentiment label counts:
# sentiment_label
# Positive    126
# Negative    114
# Neutral      51
# Name: count, dtype: int64
#
# Sentiment score summary:
# count    291.000000
# mean       0.058330
# std        0.613851
# min       -1.000000
# 25%       -0.424500
# 50%        0.034000
# 75%        0.558500
# max        1.000000
# Name: sentiment_score, dtype: float64
#     post_id     platform            bank_name  \
# 11  P000012         Yelp           GlobalBank
# 16  P000017       Forums         Horizon Bank
# 17  P000018       Reddit       Pioneer Credit
# 29  P000030  Google Play        Maple Savings
# 46  P000047       Reddit        Maple Savings
# 47  P000048      Twitter           GlobalBank
# 52  P000053      Twitter         Citadel Bank
# 62  P000063         Yelp       SafeTrust Bank
# 70  P000071  Google Play  First National Bank
# 74  P000075     LinkedIn       Pioneer Credit
#
#                                             post_text  \
# 11  Cash shortage at ATM during the weekend ruined...
# 16  Why is the monthly fee increasing? Feels like ...
# 17  The banking app keeps crashing when I try to t...
# 29  Session keeps timing out while I complete form...
# 46  Loan officer was professional and the approval...
# 47  Long wait time at the branch and only one tell...
# 52  Received phishing email pretending to be the b...
# 62  Cash shortage at ATM during the weekend ruined...
# 70  Exchange rate was competitive and transfer arr...
# 74  Savings interest rates are abysmal compared to...
#
#                    category               subcategory sentiment_label  \
# 11              Atm Service             Cash Shortage        Negative
# 16           Fees & Charges              Monthly Fees        Negative
# 17          App Performance              Login Issues        Negative
# 29           Online Banking           Feature Request        Positive
# 46             Loan Process                  Mortgage         Neutral
# 47        Branch Experience           Staff Behaviour        Negative
# 52         Security & Fraud  Unauthorized Transaction         Neutral
# 62              Atm Service              Network Down        Positive
# 70  International Transfers                 High Fees        Negative
# 74           Interest Rates          Promotional Rate        Negative
#
#     sentiment_score        date user_id  user_followers  likes  shares  \
# 11           -1.000  2024-04-07  U25860              19      2       1
# 16           -0.756  2024-07-09  U17989               9      8       0
# 17           -1.000  2024-08-06  U42271              16      2       3
# 29            0.449  2024-11-10  U92960              20      4       1
# 46            0.133  2024-06-30  U26591              81      5       0
# 47           -0.967  2023-09-16  U72616               8      3       2
# 52           -0.062  2024-11-21  U85392              51      7       1
# 62            0.391  2023-11-03  U13794               9      2       0
# 70           -0.324  2024-04-20  U49608               7      6       0
# 74           -1.000  2024-07-07  U42853              19      5       0
#
#     replies language  is_verified resolved_flag                   source_url
# 11        2       en        False           NaN  https://example.com/post/12
# 16        2       en         True           NaN  https://example.com/post/17
# 17        2       en        False           NaN  https://example.com/post/18
# 29        4       en        False           NaN  https://example.com/post/30
# 46        1       en        False           NaN  https://example.com/post/47
# 47        4       en        False         False  https://example.com/post/48
# 52        3       en        False           NaN  https://example.com/post/53
# 62        1       en        False           NaN  https://example.com/post/63
# 70        1       en        False          True  https://example.com/post/71
# 74        0       en        False           NaN  https://example.com/post/75
